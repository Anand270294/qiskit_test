# %% [markdown]
# # Test for QAOA Hamiltonian Mapper for MAX-CUT Graphs
# ## Undirected Graphs Using Networkx

# %%
# %matplotlib inline

# import math tools
import numpy as np

# import networkx
import networkx as nx

# We import plotting tools 
import matplotlib.pyplot as plt 
from   matplotlib import cm
from   matplotlib.ticker import LinearLocator, FormatStrFormatter

# importing Qiskit
from qiskit import Aer, IBMQ
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, execute

from qiskit.providers.ibmq import least_busy
from qiskit.tools.monitor import job_monitor
from qiskit.visualization import plot_histogram

# %%
#Generate a graph here using networkx
# Number of Nodes
n = 4
degree = 3

# Create the graph
G = nx.random_regular_graph(degree, n)

plt.subplot(121)

nx.draw(G,with_labels=1, pos=nx.spring_layout(G), node_color='w', edge_color='g')
# Out:
# /home/anand/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %% [markdown]
# ## Basic Mapping of the Hamiltonian for a graph with p=1

# %%
# Instansiate the Quantum circuit
hamiltonian = QuantumCircuit(len(G.nodes), len(G.nodes))

# Number of vertices added the Quantum Circuit as Hadamard gates
hamiltonian.h(range(len(G.nodes)))
hamiltonian.barrier()

gamma = 1.8
beta = 2.7

# Use the edge list to generate Cost-Hamiltonian
for e in G.edges:
    hamiltonian.cx(e[0],e[1])
    hamiltonian.rz(gamma, e[1])
    hamiltonian.cx(e[0],e[1])
    
hamiltonian.barrier()

# Generate the Mixer Hamiltonian 
hamiltonian.rx(beta,range(len(G.nodes)))

hamiltonian.barrier()
hamiltonian.measure(range(len(G.nodes)),range(len(G.nodes)))
hamiltonian.draw(output='mpl')

# %%
# run on local simulator
backend      = Aer.get_backend("qasm_simulator")
shots        = 10000

simulate     = execute(hamiltonian, backend=backend, shots=shots)
Hamil_results = simulate.result()

plot_histogram(Hamil_results.get_counts(),figsize = (15,10),bar_labels = False)

# %% [markdown]
# ## Here need the process of calculating the Expectation value of the result

# %%
counts = Hamil_results.get_counts()

expecation_value = 0
#To calculate the expecation value of the Results
# to maintain consistency we let '0' be -1 and '1' be 1 for the partitioning
for c in counts:
    # Classical Algorithm for the MAX-CUT problem
    x = 0

    for e in G.edges:

            if c[e[0]] == "0":
                sig1 = -1
            else :
                sig1 = 1
                
            if c[e[1]] == "0":
                sig2 = -1
            else:
                sig2 = 1
                
            x += 0.5 * (1 - (sig1 * sig2))
    
    expecation_value += (counts[c] / shots) * x
    
    
# Show the expectation value of the Simulator
print(expecation_value)
# Out:
# 3.0571999999999995

# %% [markdown]
# ## Create a function to edit the circuits' gamma,beta params

# %%
def modify_params(hamiltonian,gamma, beta):
    # Instansiate the Quantum circuit
    hamiltonian = QuantumCircuit(len(G.nodes), len(G.nodes))

    # Number of vertices added the Quantum Circuit as Hadamard gates
    hamiltonian.h(range(len(G.nodes)))
    hamiltonian.barrier()

    # Use the edge list to generate Cost-Hamiltonian
    for e in G.edges:
        hamiltonian.cx(e[0],e[1])
        hamiltonian.rz(gamma, e[1])
        hamiltonian.cx(e[0],e[1])
    
    hamiltonian.barrier()

    # Generate the Mixer Hamiltonian 
    hamiltonian.rx(beta,range(len(G.nodes)))

    hamiltonian.barrier()
    hamiltonian.measure(range(len(G.nodes)),range(len(G.nodes)))
                                                  
    return hamiltonian

# %% [markdown]
# ## Create a function to calculate the Expectation value

# %%
def expecation_value(Hamil_results):
    counts = Hamil_results.get_counts()

    expecation_value = 0
    #To calculate the expecation value of the Results
    # to maintain consistency we let '0' be -1 and '1' be 1 for the partitioning
    for c in counts:
        # Classical Algorithm for the MAX-CUT problem
        x = 0

        for e in G.edges:

                if c[e[0]] == "0":
                    sig1 = -1
                else :
                    sig1 = 1

                if c[e[1]] == "0":
                    sig2 = -1
                else:
                    sig2 = 1

                x += 0.5 * (1 - (sig1 * sig2))

        expecation_value += (counts[c] / shots) * x
    return expecation_value

# %%
from scipy import optimize as opt
from scipy.optimize import Bounds

bounds = [[0, 2*np.pi], [0, np.pi]]
cons = []
for factor in range(len(bounds)):
    lower, upper = bounds[factor]
    l = {'type': 'ineq',
         'fun': lambda x, lb=lower, i=factor: x[i] - lb}
    u = {'type': 'ineq',
         'fun': lambda x, ub=upper, i=factor: ub - x[i]}
    cons.append(l)
    cons.append(u)
    
def QAOA(hyperparams):
    # Instansiate the Quantum circuit
    hamiltonian = QuantumCircuit(len(G.nodes), len(G.nodes))

    # Number of vertices added the Quantum Circuit as Hadamard gates
    hamiltonian.h(range(len(G.nodes)))
    hamiltonian.barrier()

    # Use the edge list to generate Cost-Hamiltonian
    for e in G.edges:
        hamiltonian.cx(e[0],e[1])
        hamiltonian.rz(hyperparams[0], e[1])
        hamiltonian.cx(e[0],e[1])
    
    hamiltonian.barrier()

    # Generate the Mixer Hamiltonian 
    hamiltonian.rx(hyperparams[1],range(len(G.nodes)))

    hamiltonian.barrier()
    hamiltonian.measure(range(len(G.nodes)),range(len(G.nodes)))
    
    backend      = Aer.get_backend("qasm_simulator")
    shots        = 10000

    simulate     = execute(hamiltonian, backend=backend, shots=shots)
    Hamil_results = simulate.result()
    
    r = -1.0 * expecation_value(Hamil_results);
    
    return r

# %%
hyperparams = [2.40514262, 0.71998964]
res = opt.minimize(QAOA, hyperparams,constraints=cons, tol= 1e-3, method='COBYLA')

# %%
print(res)
hyperparams = res.x
# Out:
#      fun: -3.6922
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 22
#   status: 1
#  success: True
#        x: array([3.61133168, 0.52055385])

# %%
p_h = modify_params(hamiltonian, hyperparams[0], hyperparams[1])

# %%
p_h.draw(output='mpl')

# %%
# run on local simulator
backend      = Aer.get_backend("qasm_simulator")
shots        = 10000

simulate     = execute(p_h, backend=backend, shots=shots)
Hamil_results = simulate.result()

plot_histogram(Hamil_results.get_counts(),figsize = (15,10),bar_labels = False)

# %% [markdown]
# ## Subgraphs in the graphs can be used to create a fixed-p algorithm
#
# ### Using a butterfly graph to understand the subgraphing issue

# %%
#Generating the butterfly graph with 5 nodes 
n     = 5
V     = np.arange(0,n,1)
E     =[(0,1,1.0),(0,2,1.0),(1,2,1.0),(3,2,1.0),(3,4,1.0),(4,2,1.0)] 

G     = nx.Graph()
G.add_nodes_from(V)
G.add_weighted_edges_from(E)

# Generate plot of the Graph
colors       = ['w' for node in G.nodes()]
default_axes = plt.axes()
pos          = nx.spring_layout(G)

nx.draw_networkx(G, node_color=colors, node_size=600, alpha=1, ax=default_axes, pos=pos)

# %% [markdown]
# ### The butterfly graph contains 2 types of graph:

# %%
# 1st type with 2 neighbouring edges:
nodes = [0,1,2]

sub_g1 =G.subgraph(nodes)

plt.subplot(121)

nx.draw(sub_g1,with_labels=1, pos=nx.spring_layout(G), node_color='w', edge_color='g')

# 2nd typer with 4 neighbouring edges:
edges = [(4,2),(3,2),(1,2),(0,1),(0,2)]

sub_g2 = G.edge_subgraph(edges)

plt.subplot(122)

nx.draw(sub_g2,with_labels=1, pos=nx.spring_layout(G), node_color='w', edge_color='g')

# %% [markdown]
# ### Generate the Cost Hamiltonian for the graph with p=1(for subgraph 1) :

# %%
# Instansiate the Quantum circuit
hamiltonian1 = QuantumCircuit(len(sub_g1.nodes), len(sub_g1.nodes))

# Number of vertices added the Quantum Circuit as Hadamard gates
hamiltonian1.h(range(len(sub_g1.nodes)))
hamiltonian1.barrier()

gamma = 1.8
beta = 2.7

# Use the edge list to generate Cost-Hamiltonian
for e in sub_g1.edges:
    hamiltonian1.cx(e[0],e[1])
    hamiltonian1.rz(gamma, e[1])
    hamiltonian1.cx(e[0],e[1])
    
hamiltonian1.barrier()

# Generate the Mixer Hamiltonian 
hamiltonian1.rx(beta,range(len(sub_g1.nodes)))

hamiltonian1.barrier()
hamiltonian1.measure(range(len(sub_g1.nodes)),range(len(sub_g1.nodes)))
hamiltonian1.draw(output='mpl')

# %% [markdown]
# ### Run the QAOA as per the previous section:

# %%
def expecation_value(Hamil_results):
    counts = Hamil_results.get_counts()

    expecation_value = 0
    #To calculate the expecation value of the Results
    # to maintain consistency we let '0' be -1 and '1' be 1 for the partitioning
    for c in counts:
        # Classical Algorithm for the MAX-CUT problem
        x = 0

        for e in sub_g1.edges:

                if c[e[0]] == "0":
                    sig1 = -1
                else :
                    sig1 = 1

                if c[e[1]] == "0":
                    sig2 = -1
                else:
                    sig2 = 1

                x += 0.5 * (1 - (sig1 * sig2))

        expecation_value += (counts[c] / shots) * x
    return expecation_value

# %%
def QAOA(hyperparams):
    # Instansiate the Quantum circuit
    hamiltonian = QuantumCircuit(len(sub_g1.nodes), len(sub_g1.nodes))

    # Number of vertices added the Quantum Circuit as Hadamard gates
    hamiltonian.h(range(len(sub_g1.nodes)))
    hamiltonian.barrier()

    # Use the edge list to generate Cost-Hamiltonian
    for e in sub_g1.edges:
        hamiltonian.cx(e[0],e[1])
        hamiltonian.rz(hyperparams[0], e[1])
        hamiltonian.cx(e[0],e[1])
    
    hamiltonian.barrier()

    # Generate the Mixer Hamiltonian 
    hamiltonian.rx(hyperparams[1],range(len(sub_g1.nodes)))

    hamiltonian.barrier()
    hamiltonian.measure(range(len(sub_g1.nodes)),range(len(sub_g1.nodes)))
    
    backend      = Aer.get_backend("qasm_simulator")
    shots        = 10000

    simulate     = execute(hamiltonian, backend=backend, shots=shots)
    Hamil_results = simulate.result()
    
    r = -1.0 * expecation_value(Hamil_results);
    
    return r

# %%
hyperparams = [2.40514262, 0.71998964]
res = opt.minimize(QAOA, hyperparams,constraints=cons, tol= 1e-3, method='COBYLA')

# %%
print(res)
hyperparams = res.x
# Out:
#      fun: -1.9998
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 25
#   status: 1
#  success: True
#        x: array([2.51383407, 0.60661463])

# %% [markdown]
# ### Run QAOA for the 2nd Subgraph

# %%
def expecation_value(Hamil_results):
    counts = Hamil_results.get_counts()

    expecation_value = 0
    #To calculate the expecation value of the Results
    # to maintain consistency we let '0' be -1 and '1' be 1 for the partitioning
    for c in counts:
        # Classical Algorithm for the MAX-CUT problem
        x = 0

        for e in sub_g2.edges:

                if c[e[0]] == "0":
                    sig1 = -1
                else :
                    sig1 = 1

                if c[e[1]] == "0":
                    sig2 = -1
                else:
                    sig2 = 1

                x += 0.5 * (1 - (sig1 * sig2))

        expecation_value += (counts[c] / shots) * x
    return expecation_value

# %%
def QAOA(hyperparams):
    # Instansiate the Quantum circuit
    hamiltonian = QuantumCircuit(len(sub_g2.nodes), len(sub_g2.nodes))

    # Number of vertices added the Quantum Circuit as Hadamard gates
    hamiltonian.h(range(len(sub_g2.nodes)))
    hamiltonian.barrier()

    # Use the edge list to generate Cost-Hamiltonian
    for e in sub_g2.edges:
        hamiltonian.cx(e[0],e[1])
        hamiltonian.rz(hyperparams[0], e[1])
        hamiltonian.cx(e[0],e[1])
    
    hamiltonian.barrier()

    # Generate the Mixer Hamiltonian 
    hamiltonian.rx(hyperparams[1],range(len(sub_g2.nodes)))

    hamiltonian.barrier()
    hamiltonian.measure(range(len(sub_g2.nodes)),range(len(sub_g2.nodes)))
    
    backend      = Aer.get_backend("qasm_simulator")
    shots        = 10000

    simulate     = execute(hamiltonian, backend=backend, shots=shots)
    Hamil_results = simulate.result()
    
    r = -1.0 * expecation_value(Hamil_results);
    
    return r

# %%
hyperparams = [2.40514262, 0.71998964]
res = opt.minimize(QAOA, hyperparams,constraints=cons, tol= 1e-3, method='COBYLA')

# %%
print(res)
hyperparams = res.x
# Out:
#      fun: -2.7106999999999997
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 31
#   status: 1
#  success: True
#        x: array([2.76770675, 0.6394869 ])

# %%
expectation = 2*1.9998 + 4*2.7106
print(expectation)
# Out:
# 14.841999999999999
